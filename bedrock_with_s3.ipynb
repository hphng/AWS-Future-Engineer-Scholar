# %%
import boto3
import json

# %%
s3 = boto3.client("s3", region_name="us-east-1")
response = s3.get_object(
    Bucket="huy-udacity",
    Key='heros.txt'
)

heros = response['Body'].read().decode('utf-8')
# print(heros[:500])  

response = s3.get_object(
    Bucket="huy-udacity",
    Key='transcript.txt'
)

transcript = response['Body'].read().decode('utf-8')

# %%
client = boto3.client('bedrock-runtime', region_name='us-east-1')

# %%
model_id = "anthropic.claude-3-sonnet-20240229-v1:0"

# %%
prompt_text = f"""
<context>
{heros}
</context>

<instruction>
You are a creative story teller. Given a text, you create a positive high energy story. You stay to the facts of the story while still making it engaging.
You are to create a story that captures the main topics of the text. The story should be no more than 500 words.
</instruction>

<text>
{transcript}
</text>
"""

# %%
request_body = {
    "anthropic_version": "bedrock-2023-05-31",
    "max_tokens": 1024,
    "temperature": 1,
    'top_p': 0.999,
    "messages": [
        {
            "role": "user",
            "content": [{"type": "text", "text": prompt_text}]
        }
    ]
}

# %%
response = client.invoke_model(
    modelId=model_id,
    body=json.dumps(request_body)
)

# %%
# Parse the response
response_body = json.loads(response['body'].read())
generated_text = response_body['content'][0]['text']
print(generated_text)
# Out:
# Here is a 500 word high energy story capturing the main events from the text:
#
# The Valley of Echoes hummed with ancient power as Arin and Lira crested the ridge. Arin could feel the magic tingling against his skin, as if the very land was watching their approach with great anticipation.
#
# "You feel that too, don't you?" Lira said, her copper hair shimmering like molten metal in the faint light. "This place is alive with old sorcery."
#
# Arin nodded, tightening his grip on his oak staff. "I can sense it. Like whispers from the past carried on the wind."
#
# "Well those whispers better get ready for one hell of a story," Lira grinned fiercely. "Because we're about to rewrite history by taking down Morvath the Shadow Bender!"
#
# Her boldness bolstered Arin's resolve. Lira was a force unto herself - unstoppable and fueled by a spirit that wouldn't allow defeat. He wished he could share her unshakable confidence as they moved to confront the dark villain.
#
# "You look troubled, my friend," Lira observed, seeing the crease in his brow. "Speak your worries aloud. We are strongest when we face our fears together."
#
# "I am afraid I will falter when the time comes to wield the power of the Heart of Dawn," Arin admitted. "That the ancient relic will sense my weakness and choose another as its bearer."
#
# Lira threw back her head and laughed, the sound startlingly bright amidst the looming darkness. "You silly man! The Heart will choose you precisely because of your humility and good heart. Those with true strength don't need to constantly prove their power."
#
# Her words rang with a simple truth that eased Arin's anxiety. He stood a little taller as they pressed on to meet their companions - the unflappable Seron, the mysterious Elora, and the mighty mage Thalen. Together they made an unlikely band of heroes, bound by circumstance and friendship rather than destiny.
#
# Before long, the dark shape of Morvath emerged through the shadowed valley like a sinister spectre. Arin felt his pulse quicken, but Lira's steady presence beside him was reassuring.
#
# "Remember, when Morvath unleashes his power, hesitation becomes our deadliest foe," she murmured. "Strike without pause, without doubt. You can do this, Arin."
#
# Then the battle was upon them in a cacophony of clashing blades, thunderous spells, and the eerie screech of shadow magic. Arin fought with every scrap of courage, his humble staff blazing with the defiant light of the ages.
#
# When at last he stood alone before the ancient vault containing the Heart of Dawn, Morvath's wrath bore down with overwhelming force. But in that moment, Arin's belief in himself crystalized. He was the world's final hope, the chosen bearer of its most profound power.
#
# Drawing the blinding energy of the Heart into his very being, Arin emerged as a radiant beacon that turned back the smothering darkness. Morvath's conquest crumbled to ruin before the blazing light of Arin's intent - to protect, to persevere, to triumph over evil.
#
# As the shadows dissipated, Arin's friends surrounded him with eyes shining bright with victory and profound belief in the humble hero. For in the end, it was not might that carried the day, but the blazing courage of an ordinary soul when called to extraordinary purpose.
